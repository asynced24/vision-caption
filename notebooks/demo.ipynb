# %% [markdown]
# # Vision Caption Demo
#
# This notebook is a lightweight walkthrough of the inference-only API.
# It does **not** include any training code.

# %%
from vision_caption import load_model

model = load_model()
caption = model.generate("path/to/image.jpg")
print(caption)
